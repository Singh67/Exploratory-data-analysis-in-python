# %%
from matplotlib import rcParams
import plotly.tools as tls
import plotly.offline as py
from plotly.offline import init_notebook_mode,iplot,plot
from plotly.graph_objs import *
init_notebook_mode(connected=True)
import warnings
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
import numpy as np
import pandas as pd

# %%
companies=pd.read_csv('CompaniesRevenueEmployees.csv',encoding = 'unicode_escape',index_col=0)

# %%
companies['Text']=companies.apply(lambda x: "<b>{}</b><i>{}</i><br>Revenue:${} billion<br> Employee{:,}".format(x['Name'],
                                  x['Industry'],x['Revenue (USD billions)'],x['Employees']),axis=1)

# %%
companies.loc[10,'Text']
# Out:
# '<b>Volkswagen</b><i>Automotive</i><br>Revenue:$245 billion<br> Employee572,800'

# %%
companiesTrace={'type':'scatter',
                'mode':'markers',
                'x':companies['Revenue (USD billions)'],
                'y':companies['Employees'],
                'text': companies['Text'],
                'hoverinfo':'text'}

layout={'title':'Revenue by number of employees',
        'xaxis':{'title':'Revenue (Billion $)'},
        'yaxis':{'title':'Employee'},
        'hovermode':'closest'}

# %%
data=Data([companiesTrace])
fig=Figure(data=data,layout=layout)
iplot(fig)
# Out:
# C:\Users\Satish\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
# ...

# %%
#Styling the marker points

# %%
companiesTrace.update({'marker' :{'symbol':'square-open'}})
data=Data([companiesTrace])
fig=Figure(data=data,layout=layout)
iplot(fig)
# Out:
# C:\Users\Satish\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
# ...

# %%
companiesTrace.update({'marker' :{'opacity':0.7}})
data=Data([companiesTrace])
fig=Figure(data=data,layout=layout)
iplot(fig)
# Out:
# C:\Users\Satish\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
# ...

# %%
companiesTrace.update({'marker' :{'color':'#6a5acd'}})
data=Data([companiesTrace])
fig=Figure(data=data,layout=layout)
iplot(fig)
# Out:
# C:\Users\Satish\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
# ...

# %%
companiesTrace.update({'marker' :{'line':{'width':1.5,'color':'black'},'size':10}})
data=Data([companiesTrace])
fig=Figure(data=data,layout=layout)
iplot(fig)
# Out:
# C:\Users\Satish\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
# ...

# %%
#Plotting different categories on the same plot

# %%
iris=pd.read_csv('irisDataset.csv',index_col=0)

# %%
iris.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width    Species
# 0           5.1          3.5           1.4          0.2  I. setosa
# 1           4.9          3.0           1.4          0.2  I. setosa
# 2           4.7          3.2           1.3          0.2  I. setosa
# 3           4.6          3.1           1.5          0.2  I. setosa
# 4           5.0          3.6           1.4          0.2  I. setosa

# %%
irisSpeciesUnique=list(iris['Species'].unique())
irisSpeciesUnique
# Out:
# ['I. setosa', 'I. versicolor', 'I. virginica']

# %%
traces=[]

for species in irisSpeciesUnique:
    traces.append({'type':'scatter',
                   'mode':'markers',
                   'x':iris.loc[iris['Species']==species,'Sepal length'],
                   'y':iris.loc[iris['Species']==species,'Sepal width'],
                   'name': species})

# %%
layout={'title':'Sepal length and width for iris setosa, versicolor,virginica',
        'xaxis':{'title':'Sepal lenght(cm)',
                  'range':[iris['Sepal length'].min() *.95,iris['Sepal length'].max() *1.05]},
        'yaxis':{'title': 'Sepal width',
                'range':[iris['Sepal width'].min() *.95,iris['Sepal width'].max() *1.05]}}
                        
fig=Figure(data=traces,layout=layout)

# %%
iplot(fig)
# Out:
# <div id="59f52f32-36b3-431e-ab9e-43889ecd3150" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("59f52f32-36b3-431e-ab9e-43889ecd3150", [{"mode": "markers", "name": "I. setosa", "x": [5.1, 4.9, 4.7, 4.6, 5.0, 5.4, 4.6, 5.0, 4.4, 4.9, 5.4, 4.8, 4.8, 4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5.0, 5.0, 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5.0, 5.5, 4.9, 4.4, 5.1, 5.0, 4.5, 4.4, 5.0, 5.1, 4.8, 5.1, 4.6, 5.3, 5.0], "y": [3.5, 3.0, 3.2, 3.1, 3.6, 3.9, 3.4, 3.4, 2.9, 3.1, 3.7, 3.4, 3.0, 3.0, 4.0, 4.4, 3.9, 3.5, 3.8, 3.8, 3.4, 3.7, 3.6, 3.3, 3.4, 3.0, 3.4, 3.5, 3.4, 3.2, 3.1, 3.4, 4.1, 4.2, 3.1, 3.2, 3.5, 3.6, 3.0, 3.4, 3.5, 2.3, 3.2, 3.5, 3.8, 3.0, 3.8, 3.2, 3.7, 3.3], "type": "scatter", "uid": "56e5085c-ecb5-496a-9863-99ce31418d95"}, {"mode": "markers", "name": "I. versicolor", "x": [7
# ...
