# %%
from matplotlib import rcParams
import plotly.tools as tls
import plotly.offline as py
from plotly.offline import init_notebook_mode,iplot,plot
from plotly.graph_objs import *
init_notebook_mode(connected=True)
import warnings
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
import numpy as np
import pandas as pd

# %%
emissions=pd.read_csv('Co2EmissionsPerCapitaByCountry.csv',index_col=0)

# %%
emissions.head()
# Out:
#    Year  Afghanistan | AFG  Albania | ALB  Algeria | DZA  \
# 0  1960           0.046068       1.258195       0.553764
# 1  1961           0.053615       1.374186       0.531810
# 2  1962           0.073781       1.439956       0.484954
# 3  1963           0.074251       1.181681       0.452824
# 4  1964           0.086317       1.111742       0.459569
#
#    American Samoa | ASM  Andorra | AND  Angola | AGO  \
# 0                   NaN            NaN      0.104357
# 1                   NaN            NaN      0.084718
# 2                   NaN            NaN      0.216025
# 3                   NaN            NaN      0.206877
# 4                   NaN            NaN      0.216174
#
#    Antigua and Barbuda | ATG  Arab World | ARB  Argentina | ARG  \
# 0                   0.670617          0.643964         2.367473
# 1                   0.860441          0.685501         2.442616
# 2                   1.823374          0.761148         2.522392
# 3                   1.470175          0.875124         2.316356
# 4                   1.567094          0.999248         2.538380
#
#         ...        Uzbekistan | UZB  Vanuatu | VUT  Venezuela, RB | VEN  \
# 0       ...                     NaN            NaN             7.005107
# 1       ...                     NaN            NaN             6.136886
# 2       ...                     NaN       0.594888             6.155057
# 3       ...                     NaN       0.471728             6.155748
# 4       ...                     NaN       0.864247             5.973226
#
#    Vietnam | VNM  Virgin Islands (U.S.) | VIR  West Bank and Gaza | PSE  \
# 0       0.215631                          NaN                       NaN
# 1       0.225435                          NaN                       NaN
# 2       0.258760                          NaN                       NaN
# 3       0.247579                          NaN                       NaN
# 4       0.314058                          NaN                       NaN
#
#    World | WLD  Yemen, Rep. | YEM  Zambia | ZMB  Zimbabwe | ZWE
# 0     3.096137           0.703403           NaN             NaN
# 1     3.067052           0.507631           NaN             NaN
# 2     3.138003           0.728004           NaN             NaN
# 3     3.242342           0.537606           NaN             NaN
# 4     3.358670           0.658012      0.950434        1.045374
#
# [5 rows x 249 columns]

# %%
columnNames=emissions.columns.tolist()

# %%
UkEmissions={'type':'scatter',
             'x':emissions['Year'],
             'y':emissions['United Kingdom | GBR'],
             'mode':'lines',
             'name': 'UK C02 Emission'
            }
layout={'title':'C02 emission in kilons for UK, 1960-2015',
        'xaxis':{'title':'Year'},
        'yaxis':{'title':'Co2 Emission (kt)'}
       }
data=Data([UkEmissions])

fig=Figure(data=data,layout=layout)
iplot(fig)
# Out:
# C:\Users\Satish\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
# <div id="cf2156a1-0341-4ade-a921-ad9cb8a69c64" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cf2156a1-0341-4ade-a921-ad9cb8a69c64", [{"mode": "lines", "name": "UK C02 Emission", "x": [1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011], "y":
[1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011], "type": "scatter", "uid": "1bbba293-8314-4116-82cc-00612ed9628d"}], {"title": "C02 emission in kilons for UK, 1960-2015", "xaxis": {"title": "Co2 Emission (kt)"}, "yaxis": {"title": "Year"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("961e71f3-1f6b-458e-886d-143df5140abe"));});</script>

# %%
#Stacked Area chart

# %%
columnSelection=['United Arab Emirates | ARE','United Kingdom | GBR','United States | USA',
                  'China | CHN','India | IND','Year']

stackedAreaData=emissions.loc[:,(columnSelection)]

stackedAreaData.head()
# Out:
#    United Arab Emirates | ARE  United Kingdom | GBR  United States | USA  \
# 0                    0.118786             11.150759            15.999779
# 1                    0.108937             11.154139            15.681256
# 2                    0.163355             11.142928            16.013938
# 3                    0.175712             11.254853            16.482762
# 4                    0.132651             11.265839            16.968119
#
#    China | CHN  India | IND  Year
# 0     1.170381     0.268161  1960
# 1     0.836047     0.284292  1961
# 2     0.661428     0.306519  1962
# 3     0.640002     0.322533  1963
# 4     0.625646     0.308900  1964

# %%
UnitedArabEmirates={'type':'scatter',
             'x':stackedAreaData['Year'],
             'y':stackedAreaData['United Arab Emirates | ARE'],
             'mode':'lines',
             'fill':'tonexty',
             'name': 'UAE C02 Emission'
            }

UnitedKingdom ={'type':'scatter',
             'x':stackedAreaData['Year'],
             'y':stackedAreaData['United Arab Emirates | ARE'] + stackedAreaData['United Kingdom | GBR'],
             'mode':'lines',
             'fill':'tonexty',
             'name': 'GBR C02 Emission'
            }


UnitedStates ={'type':'scatter',
             'x':stackedAreaData['Year'],
             'y':stackedAreaData['United Arab Emirates | ARE'] + stackedAreaData['United Kingdom | GBR'] +
                  stackedAreaData['United States | USA'],
             'mode':'lines',
             'fill':'tonexty',
             'name': 'USA C02 Emission'
            }

China ={'type':'scatter',
             'x':stackedAreaData['Year'],
             'y':stackedAreaData['United Arab Emirates | ARE'] + stackedAreaData['United Kingdom | GBR'] +
                  stackedAreaData['United States | USA'] + stackedAreaData['China | CHN'],
             'mode':'lines',
             'fill':'tonexty',
             'name': 'China C02 Emission'
            }

India={'type':'scatter',
             'x':stackedAreaData['Year'],
             'y':stackedAreaData['United Arab Emirates | ARE'] + stackedAreaData['United Kingdom | GBR'] +
                  stackedAreaData['United States | USA'] + stackedAreaData['China | CHN'] +
                  stackedAreaData['India | IND'],
             'mode':'lines',
             'fill':'tonexty',
             'name': 'India C02 Emission'
            }
data=Data([UnitedArabEmirates,UnitedKingdom,UnitedStates,China,India])
# Out:
# C:\Users\Satish\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.

# %%
layout={'title':'C02 emission in kilons, 1960-2015',
        'xaxis':{'title':'Year'},
        'yaxis':{'title':'Co2 Emission (kt)'}
       }

# %%
fig=Figure(data=data, layout=layout)

# %%
iplot(fig)
# Out:
# <div id="4f1cef8b-f055-4ec0-8a97-bb64946304af" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4